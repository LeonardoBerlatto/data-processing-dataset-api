# %% [markdown]
# ## Notebook
# This notebook is only ment for testing pandas methods before implementation

# %%
import pandas as pd

df = pd.read_csv('../resources/data/sales.csv')

df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df['Invoice ID'].unique()
# Out:
# array(['750-67-8428', '226-31-3081', '631-41-3108', '123-19-1176',
#        '373-73-7910', '699-14-3026', '355-53-5943', '315-22-5665',
#        '665-32-9167', '692-92-5582', '351-62-0822', '529-56-3974',
#        '365-64-0515', '252-56-2699', '829-34-3910', '299-46-1805',
#        '656-95-9349', '765-26-6951', '329-62-1586', '319-50-3348',
#        '300-71-4605', '371-85-5789', '273-16-6619', '636-48-8204',
#        '549-59-1358', '227-03-5010', '649-29-6775', '189-17-4241',
#        '145-94-9061', '848-62-7243', '871-79-8483', '149-71-6266',
#        '640-49-2076', '595-11-5460', '183-56-6882', '232-16-2483',
#        '129-29-8530', '272-65-1806', '333-73-7901', '777-82-7220',
#        '280-35-5823', '554-53-8700', '354-25-5821', '228-96-1411',
#        '617-15-4209', '132-32-9879', '370-41-7321', '727-46-3608',
#        '669-54-1719', '574-22-5561', '326-78-5178', '162-48-8011',
#        '616-24-2851', '778-71-5554', '242-55-6721', '399-46-5918',
# ...

# %% [markdown]
# ### Reading data

# %%
df = df.set_index('Invoice ID')

df.head().columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
df.drop('750-67-8428')
# Out:
#             Branch       City Customer type  Gender            Product line  \
# Invoice ID
# 226-31-3081      C  Naypyitaw        Normal  Female  Electronic accessories
# 631-41-3108      A     Yangon        Normal    Male      Home and lifestyle
# 123-19-1176      A     Yangon        Member    Male       Health and beauty
# 373-73-7910      A     Yangon        Normal    Male       Sports and travel
# 699-14-3026      C  Naypyitaw        Normal    Male  Electronic accessories
# ...            ...        ...           ...     ...                     ...
# 233-67-5758      C  Naypyitaw        Normal    Male       Health and beauty
# 303-96-2227      B   Mandalay        Normal  Female      Home and lifestyle
# 727-02-1313      A     Yangon        Member    Male      Food and beverages
# 347-56-2442      A     Yangon        Normal    Male      Home and lifestyle
# 849-09-3807      A     Yangon        Member  Female     Fashion accessories
#
# ...

# %%
'226-31-3081' in df.index
# Out:
# True

# %%
# Out:
# Branch  City       Customer type  Gender  Product line            Unit price  Quantity  Tax 5%   Total     Date       Time   Payment      cogs    gross margin percentage  gross income  Rating
# A       Yangon     Member         Female  Electronic accessories  17.42       10        8.7100   182.9100  2/22/2019  12:30  Ewallet      174.20  4.761905                 8.7100        7.0       1
# B       Mandalay   Normal         Male    Sports and travel       97.74       4         19.5480  410.5080  3/12/2019  19:53  Ewallet      390.96  4.761905                 19.5480       6.4       1
#                                                                   44.63       6         13.3890  281.1690  1/2/2019   20:08  Credit card  267.78  4.761905                 13.3890       5.1       1
#                                                                   46.42       3         6.9630   146.2230  1/4/2019   13:24  Credit card  139.26  4.761905                 6.9630        4.4       1
# ...
